# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("taxis")

# %%
df.head()
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan
# 3         Yorkville West      Manhattan       Manhattan
# 4         Yorkville West      Manhattan       Manhattan

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   object
#  1   dropoff          6433 non-null   object
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 703.7+ KB

# %%
df.describe()
# Out:
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# std       1.203768     3.827867    11.551804     2.44856     1.415267
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# 50%       1.000000     1.640000     9.500000     1.70000     0.000000
# 75%       2.000000     3.210000    15.000000     2.80000     0.000000
# max       6.000000    36.700000   150.000000    33.20000    24.020000
#
#              total
# count  6433.000000
# mean     18.517794
# std      13.815570
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
df.shape
# Out:
# (6433, 14)

# %%
sns.set_theme(style="dark")

# %%
plt.title('Heatmap for taxis')
sns.heatmap(df.corr(), annot = True, cmap = 'cividis', cbar = False)
plt.show()

# %%
plt.title('Heatmap for checking null value exists or not')
sns.heatmap(df.isnull())
plt.show()

# %%
df['pickup_zone'].nunique()
# Out:
# 194

# %%
df['payment'].nunique()
# Out:
# 2

# %%
df['payment'].fillna(df['payment'].mode, inplace = True)

# %%
df['dropoff_borough'].fillna(df['dropoff_borough'].mode, inplace = True)

# %%
df['pickup_borough'].fillna(df['pickup_borough'].mode, inplace = True)

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment             0
# pickup_zone        26
# dropoff_zone       45
# pickup_borough      0
# dropoff_borough     0
# dtype: int64

# %%
df.shape
# Out:
# (6433, 14)

# %%
df1 = df.dropna()

# %%
df1.shape
# Out:
# (6383, 14)

# %%
df1.reset_index()
# Out:
#       index               pickup              dropoff  passengers  distance  \
# 0         0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60
# 1         1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79
# 2         2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37
# 3         3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70
# 4         4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16
# ...     ...                  ...                  ...         ...       ...
# 6378   6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75
# 6379   6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74
# 6380   6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14
# 6381   6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12
# 6382   6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85
#
#       fare   tip  tolls  total   color      payment            pickup_zone  \
# 0      7.0  2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1      5.0  0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2      7.5  2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     27.0  6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4      9.0  1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...   ...    ...    ...     ...          ...                    ...
# 6378   4.5  1.06    0.0   6.36   green  credit card      East Harlem North
# 6379  58.0  0.00    0.0  58.80   green  credit card                Jamaica
# 6380  16.0  0.00    0.0  17.30   green         cash    Crown Heights North
# 6381   6.0  0.00    0.0   6.80   green  credit card          East New York
# 6382  15.0  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6378              Central Harlem North      Manhattan       Manhattan
# 6379  East Concourse/Concourse Village         Queens           Bronx
# 6380                    Bushwick North       Brooklyn        Brooklyn
# 6381      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6382                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6383 rows x 15 columns]

# %%
df1.isnull().sum() # NO null value exist here.
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %%
plt.title('Heatmap for checking null value exists or not')
sns.heatmap(df1.isnull())
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6383 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6383 non-null   object
#  1   dropoff          6383 non-null   object
#  2   passengers       6383 non-null   int64
#  3   distance         6383 non-null   float64
#  4   fare             6383 non-null   float64
#  5   tip              6383 non-null   float64
#  6   tolls            6383 non-null   float64
#  7   total            6383 non-null   float64
#  8   color            6383 non-null   object
#  9   payment          6383 non-null   object
#  10  pickup_zone      6383 non-null   object
#  11  dropoff_zone     6383 non-null   object
#  12  pickup_borough   6383 non-null   object
#  13  dropoff_borough  6383 non-null   object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 748.0+ KB

# %%
df1.head(6)
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
# 5  2019-03-11 10:37:23  2019-03-11 10:47:31           1      0.49   7.5  2.16
#
#    tolls  total   color      payment                pickup_zone  \
# 0    0.0  12.95  yellow  credit card            Lenox Hill West
# 1    0.0   9.30  yellow         cash      Upper West Side South
# 2    0.0  14.16  yellow  credit card              Alphabet City
# 3    0.0  36.95  yellow  credit card                  Hudson Sq
# 4    0.0  13.40  yellow  credit card               Midtown East
# 5    0.0  12.96  yellow  credit card  Times Sq/Theatre District
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan
# 3         Yorkville West      Manhattan       Manhattan
# 4         Yorkville West      Manhattan       Manhattan
# 5           Midtown East      Manhattan       Manhattan

# %%
plt.title('Scatter plot between tips and total')
plt.xlabel('Total')
plt.ylabel('Tip')
sns.scatterplot(x= df1['total'], y = df1['tip'])
plt.show()

# %%
plt.title('Countplot for payment method')
sns.countplot(df1['payment'])
plt.show()

# %%
sns.lmplot(x = 'fare', y = 'distance', data = df1, line_kws={'color': 'orange'},
           scatter_kws={"s": 10, "alpha": 0.5, 'color':'orange'}) 
#  Here, outliers have been removed.
plt.xlabel('Fare')
plt.title("Line plot between fare and distance
plt.ylabel('Distance')
plt.show()
# Out:
#   File "C:\Users\gm969\AppData\Local\Temp\ipykernel_19180\1028062859.py", line 5
#     plt.title("Line plot between fare and distance
#                                                   ^
# SyntaxError: EOL while scanning string literal

# %%
df1[df1['distance']>35]

# %%
df2 = df1[df1.distance != 36.7]

# %%
df2.shape

# %%
sns.lmplot(x = 'fare', y = 'distance', data = df2, line_kws={'color': 'orange'},
           scatter_kws={"s": 10, "alpha": 0.5, 'color':'orange'}) 
#  Here, outliers have been removed.
plt.xlabel('Fare')
plt.ylabel('Distance')
plt.title("Line plot between fare and distance")
plt.show()

# %%
df2['color'].value_counts()

# %%
plt.title("Count plot for taxi's color")
sns.countplot(x=df2["color"])
plt.show()
